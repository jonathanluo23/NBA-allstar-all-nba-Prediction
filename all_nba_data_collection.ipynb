# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanluo23/NBA-allstar-all-nba-Prediction/blob/main/all_nba_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

# %%
season_id = '2021-22'
per_mode = 'PerGame'

# %%
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='

# %%
headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
response = requests.get(url=player_info_url, headers=headers).json()

# %%
player_info = response['resultSets'][0]['rowSet']

# %%
columns_list = ["PLAYER_ID"
,"PLAYER_NAME"
,"NICKNAME"
,"TEAM_ID"
,"TEAM_ABBREVIATION"
,"AGE"
,"GP"
, "W"
, "L"
,"W_PCT"
,"MIN"
,"FGM"
,"FGA"
,"FG_PCT"
,"FG3M"
, "FG3A"
,"FG3_PCT"
, "FTM"
, "FTA"
, "FT_PCT"
, "OREB"
, "DREB"
,"REB"
, "AST"
, "TOV"
, "STL"
, "BLK"
,"BLKA"
, "PF"
, "PFD"
,"PTS"
,"PLUS_MINUS"
, "NBA_FANTASY_PTS"
, "DD2"
,"TD3"
, "WNBA_FANTASY_PTS"
, "GP_RANK"
,"W_RANK"
,"L_RANK"
, "W_PCT_RANK"
, "MIN_RANK"
, "FGM_RANK"
, "FGA_RANK"
, "FG_PCT_RANK"
, "FG3M_RANK"
, "FG3A_RANK"
, "FG3_PCT_RANK"
, "FTM_RANK"
, "FTA_RANK"
, "FT_PCT_RANK"
, "OREB_RANK"
, "DREB_RANK"
, "REB_RANK"
,"AST_RANK"
, "TOV_RANK"
,"STL_RANK"
, "BLK_RANK"
,"BLKA_RANK"
,"PF_RANK"
,"PFD_RANK"
,"PTS_RANK"
,"PLUS_MINUS_RANK"
, "NBA_FANTASY_PTS_RANK"
,"DD2_RANK"
,"TD3_RANK"
,"WNBA_FANTASY_PTS_RANK"
,"CFID"
,"CFPARAMS"]

# %%
trad_22 = pd.DataFrame(player_info, columns=columns_list)

# %%
trad_22
# Out:
#      PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W   L  W_PCT  \
# 0       203932     Aaron Gordon    Aaron  1610612743               DEN  26.0  75  46  29  0.613
# 1      1630565      Aaron Henry    Aaron  1610612755               PHI  22.0   6   6   0  1.000
# 2      1628988    Aaron Holiday    Aaron  1610612756               PHX  25.0  63  34  29  0.540
# 3      1630174    Aaron Nesmith    Aaron  1610612738               BOS  22.0  52  32  20  0.615
# 4      1630598    Aaron Wiggins    Aaron  1610612760               OKC  23.0  50  13  37  0.260
# ..         ...              ...      ...         ...               ...   ...  ..  ..  ..    ...
# 600     203897      Zach LaVine     Zach  1610612741               CHI  27.0  67  37  30  0.552
# 601    1630285   Zavier Simpson   Zavier  1610612760               OKC  25.0   4   1   3  0.250
# 602    1630192       Zeke Nnaji     Zeke  1610612743               DEN  21.0  41  24  17  0.585
# ...

# %%
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME"]]

# %%
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]

# %%
real_trad_22
# Out:
#      PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W   L  W_PCT  \
# 0       203932     Aaron Gordon    Aaron  1610612743               DEN  26.0  75  46  29  0.613
# 1      1630565      Aaron Henry    Aaron  1610612755               PHI  22.0   6   6   0  1.000
# 2      1628988    Aaron Holiday    Aaron  1610612756               PHX  25.0  63  34  29  0.540
# 3      1630174    Aaron Nesmith    Aaron  1610612738               BOS  22.0  52  32  20  0.615
# 4      1630598    Aaron Wiggins    Aaron  1610612760               OKC  23.0  50  13  37  0.260
# ..         ...              ...      ...         ...               ...   ...  ..  ..  ..    ...
# 600     203897      Zach LaVine     Zach  1610612741               CHI  27.0  67  37  30  0.552
# 601    1630285   Zavier Simpson   Zavier  1610612760               OKC  25.0   4   1   3  0.250
# 602    1630192       Zeke Nnaji     Zeke  1610612743               DEN  21.0  41  24  17  0.585
# ...

# %% [markdown]
# #advanced

# %%
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='

# %%
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()

# %%
player_info_adv = response_adv['resultSets'][0]['rowSet']

# %%
columns_list_adv = ["PLAYER_ID",
"PLAYER_NAME",
"NICKNAME",
"TEAM_ID",
"TEAM_ABBREVIATION",
"AGE",
"GP",
"W",
"L",
"W_PCT",
"MIN",
"E_OFF_RATING",
"OFF_RATING",
"sp_work_OFF_RATING",
"E_DEF_RATING",
"DEF_RATING",
"sp_work_DEF_RATING",
"E_NET_RATING",
"NET_RATING",
"sp_work_NET_RATING",
"AST_PCT",
"AST_TO",
"AST_RATIO",
"OREB_PCT",
"DREB_PCT",
"REB_PCT",
"TM_TOV_PCT",
"E_TOV_PCT",
"EFG_PCT",
"TS_PCT",
"USG_PCT",
"E_USG_PCT",
"E_PACE",
"PACE",
"PACE_PER40",
"sp_work_PACE",
"PIE",
"POSS",
"FGM",
"FGA",
"FGM_PG",
"FGA_PG",
"FG_PCT",
"GP_RANK",
"W_RANK",
"L_RANK",
"W_PCT_RANK",
 "MIN_RANK",
 "E_OFF_RATING_RANK",
"OFF_RATING_RANK",
"sp_work_OFF_RATING_RANK",
"E_DEF_RATING_RANK",
"DEF_RATING_RANK",
"sp_work_DEF_RATING_RANK",
"E_NET_RATING_RANK",
"NET_RATING_RANK",
"sp_work_NET_RATING_RANK",
 "AST_PCT_RANK",
 "AST_TO_RANK",
"AST_RATIO_RANK",
"OREB_PCT_RANK",
 "DREB_PCT_RANK",
 "REB_PCT_RANK" ,
 "TM_TOV_PCT_RANK",
 "E_TOV_PCT_RANK",
 "EFG_PCT_RANK",
"TS_PCT_RANK",
 "USG_PCT_RANK",
"E_USG_PCT_RANK",
"E_PACE_RANK",
 "PACE_RANK",
 "sp_work_PACE_RANK",
"PIE_RANK",
"FGM_RANK",
"FGA_RANK",
"FGM_PG_RANK",
"FGA_PG_RANK",
"FG_PCT_RANK",
"CFID",
"CFPARAMS"]

# %%
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)

# %%
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]

# %%
real_trad_2_adv
# Out:
#      PLAYER_ID  GP      PLAYER_NAME  W_PCT  OFF_RATING  DEF_RATING  NET_RATING  AST_PCT  AST_TO  \
# 0       203932  75     Aaron Gordon  0.613       117.3       111.1         6.2    0.109    1.41
# 1      1630565   6      Aaron Henry  1.000        71.1       127.0       -56.0    0.000    0.00
# 2      1628988  63    Aaron Holiday  0.540       106.8       108.2        -1.4    0.223    2.28
# 3      1630174  52    Aaron Nesmith  0.615       107.3       104.3         3.0    0.057    0.71
# 4      1630598  50    Aaron Wiggins  0.260       104.5       112.6        -8.1    0.083    1.26
# ..         ...  ..              ...    ...         ...         ...         ...      ...     ...
# 600     203897  67      Zach LaVine  0.552       112.5       113.4        -0.9    0.207    1.77
# 601    1630285   4   Zavier Simpson  0.250        98.6       125.1       -26.5    0.250    3.00
# 602    1630192  41       Zeke Nnaji  0.585       107.2       110.4        -3.2    0.037    0.74
# ...

# %%
all_data_2022 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')

# %%
all_data_2022
# Out:
#      PLAYER_ID  GP_x    PLAYER_NAME_x  W_PCT_x  OFF_RATING  DEF_RATING  NET_RATING  AST_PCT  \
# 0       203932    75     Aaron Gordon    0.613       117.3       111.1         6.2    0.109
# 1      1630565     6      Aaron Henry    1.000        71.1       127.0       -56.0    0.000
# 2      1628988    63    Aaron Holiday    0.540       106.8       108.2        -1.4    0.223
# 3      1630174    52    Aaron Nesmith    0.615       107.3       104.3         3.0    0.057
# 4      1630598    50    Aaron Wiggins    0.260       104.5       112.6        -8.1    0.083
# ..         ...   ...              ...      ...         ...         ...         ...      ...
# 600     203897    67      Zach LaVine    0.552       112.5       113.4        -0.9    0.207
# 601    1630285     4   Zavier Simpson    0.250        98.6       125.1       -26.5    0.250
# 602    1630192    41       Zeke Nnaji    0.585       107.2       110.4        -3.2    0.037
# ...

# %%
all_data_2022.to_csv('all_data_2022.csv', index=False)

# %% [markdown]
# #new dfs 2021-2012

# %%
season_id = '2020-21'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2021 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2021.head()
all_data_2021.to_csv('all_data_2021.csv', index=False)

# %%
season_id = '2019-20'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2020 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2020.head()
all_data_2020.to_csv('all_data_2020.csv', index=False)

# %%
season_id = '2018-19'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2019 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2019.head()
all_data_2019.to_csv('all_data_2019.csv', index=False)

# %%
season_id = '2017-18'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2018 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2018.head()
all_data_2018.to_csv('all_data_2018.csv', index=False)

# %%
season_id = '2016-17'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2017 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2017.head()
all_data_2017.to_csv('all_data_2017.csv', index=False)

# %%
season_id = '2015-16'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2016 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2016.head()
all_data_2016.to_csv('all_data_2016.csv', index=False)

# %%
season_id = '2014-15'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2015 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2015.head()
all_data_2015.to_csv('all_data_2015.csv', index=False)

# %%
season_id = '2013-14'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2014 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2014.head()
all_data_2014.to_csv('all_data_2014.csv', index=False)

# %%
season_id = '2012-13'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2013 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2013.head()
all_data_2013.to_csv('all_data_2013.csv', index=False)

# %%
season_id = '2011-12'
per_mode = 'PerGame'
player_info_url = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response = requests.get(url=player_info_url, headers=headers).json()
player_info = response['resultSets'][0]['rowSet']
trad_22 = pd.DataFrame(player_info, columns=columns_list)
real_trad_22 = trad_22[["PLAYER_ID","PLAYER_NAME","NICKNAME","TEAM_ID","TEAM_ABBREVIATION","AGE","GP","W","L","W_PCT","MIN","FGM","FGA","FG_PCT","FG3M","FG3A","FG3_PCT","FTM","FTA","FT_PCT","OREB","DREB","REB","AST","TOV","STL","BLK","PF","PTS","PLUS_MINUS"]]
player_info_url_adv = 'https://stats.nba.com/stats/leaguedashplayerstats?College=&Conference=&Country=&DateFrom=&DateTo=&Division=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Advanced&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode='+per_mode+'&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season='+season_id+'&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision=&Weight='
response_adv = requests.get(url=player_info_url_adv, headers=headers).json()
player_info_adv = response_adv['resultSets'][0]['rowSet']
trad_2_adv = pd.DataFrame(player_info_adv, columns=columns_list_adv)
real_trad_2_adv = trad_2_adv[['PLAYER_ID','GP', 'PLAYER_NAME','W_PCT','OFF_RATING','DEF_RATING','NET_RATING','AST_PCT','AST_TO','TM_TOV_PCT',"TS_PCT","OREB_PCT","DREB_PCT","REB_PCT",'EFG_PCT',"PIE","USG_PCT","TS_PCT","PACE","POSS"]]
all_data_2012 = pd.merge(real_trad_2_adv, real_trad_22, how='inner', on = 'PLAYER_ID')
all_data_2012.head()
all_data_2012.to_csv('all_data_2012.csv', index=False)
